# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
# Matplotlib is building the font cache; this may take a moment.
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular el ingreso total de cada tienda
total_tienda1 = sum(tienda['Precio'])
total_tienda2 = sum(tienda2['Precio'])
total_tienda3 = sum(tienda3['Precio'])
total_tienda4 = sum(tienda4['Precio'])

print(f"Ingreso total de la tienda 1 {total_tienda1}")
print('######')
print(f"Ingreso total de la tienda 2 {total_tienda2}")
print('######')
print(f"Ingreso total de la tienda 3 {total_tienda3}")
print('######')
print(f"Ingreso total de la tienda 4 {total_tienda4}")

ingresos_totales = [total_tienda1, total_tienda2, total_tienda3, total_tienda4]
tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
# Out:
# Ingreso total de la tienda 1 1150880400.0
# ######
# Ingreso total de la tienda 2 1116343500.0
# ######
# Ingreso total de la tienda 3 1098019600.0
# ######
# Ingreso total de la tienda 4 1038375700.0

# %%
plt.figure(figsize=(8,5))
plt.bar(tiendas, ingresos_totales, color='skyblue', edgecolor='black')

plt.title('Ingresos totales por tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos (en $)')
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
#calcular la cantidad de productos vendidos por categoría
productos_vendidos_tienda1 = tienda.groupby('Categoría del Producto')['Producto'].count()
productos_vendidos_tienda2 = tienda2.groupby('Categoría del Producto')['Producto'].count()
productos_vendidos_tienda3 = tienda3.groupby('Categoría del Producto')['Producto'].count()
productos_vendidos_tienda4 = tienda4.groupby('Categoría del Producto')['Producto'].count()

print("Total productos vendidos por la tienda 1")
print(productos_vendidos_tienda1)
print('######')
print("Total productos vendidos por la tienda 2")
print(productos_vendidos_tienda2)
print('######')
print("Total productos vendidos por la tienda 3")
print(productos_vendidos_tienda3)
print('######')
print("Total productos vendidos por la tienda 4")
print(productos_vendidos_tienda4)
print('######')
# Out:
# Total productos vendidos por la tienda 1
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Producto, dtype: int64
# ######
# Total productos vendidos por la tienda 2
# Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# Name: Producto, dtype: int64
# ######
# Total productos vendidos por la tienda 3
# Categoría del Producto
# Artículos para el hogar    177
# Deportes y diversión       277
# Electrodomésticos          278
# Electrónicos               451
# Instrumentos musicales     177
# ...

# %%
plt.figure(figsize=(10,6))
productos_vendidos_tienda1.sort_values(ascending=True).plot(kind='barh', color='lightgreen', edgecolor='black')

plt.title('Cantidad de productos vendidos por categoría en la tienda 1')
plt.xlabel('Cantidad de ventas')
plt.ylabel('Categoría del Producto')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#calcular las calificaciones promedio de los clientes para cada tienda
promedio_tienda1 = tienda['Calificación'].mean()
promedio_tienda2 = tienda2['Calificación'].mean()
promedio_tienda3 = tienda3['Calificación'].mean()
promedio_tienda4 = tienda4['Calificación'].mean()

print(f"Calificación promedio de la tienda 1: {promedio_tienda1}")
print('######')
print(f"Calificación promedio de la tienda 2: {promedio_tienda2}")
print('######')
print(f"Calificación promedio de la tienda 3: {promedio_tienda3}")
print('######')
print(f"Calificación promedio de la tienda 4: {promedio_tienda4}")

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]
promedios_totales = [promedio_tienda1, promedio_tienda2, promedio_tienda3, promedio_tienda4]
# Out:
# Calificación promedio de la tienda 1: 3.976685036032217
# ######
# Calificación promedio de la tienda 2: 4.037303942348453
# ######
# Calificación promedio de la tienda 3: 4.048325561678677
# ######
# Calificación promedio de la tienda 4: 3.9957591178965224

# %%
plt.figure(figsize=(8,5))
plt.scatter(tiendas, promedios_totales, color='royalblue', s=100, edgecolor='black')

plt.title('Promedio de calificación por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Promedio de calificación')
plt.ylim(3.5, 4.5)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
ventas_por_producto_tienda1 = tienda['Producto'].value_counts().reset_index()
ventas_por_producto_tienda1.columns = ['Producto', 'Cantidad_Ventas']
producto_mas_vendido_tienda1 = ventas_por_producto_tienda1.iloc[0]
producto_menos_vendido_tienda1 = ventas_por_producto_tienda1.iloc[-1]

ventas_por_producto_tienda2 = tienda2['Producto'].value_counts().reset_index()
ventas_por_producto_tienda2.columns = ['Producto', 'Cantidad_Ventas']
producto_mas_vendido_tienda2 = ventas_por_producto_tienda2.iloc[0]
producto_menos_vendido_tienda2 = ventas_por_producto_tienda2.iloc[-1]

ventas_por_producto_tienda3 = tienda3['Producto'].value_counts().reset_index()
ventas_por_producto_tienda3.columns = ['Producto', 'Cantidad_Ventas']
producto_mas_vendido_tienda3 = ventas_por_producto_tienda3.iloc[0]
producto_menos_vendido_tienda3 = ventas_por_producto_tienda3.iloc[-1]

ventas_por_producto_tienda4 = tienda4['Producto'].value_counts().reset_index()
ventas_por_producto_tienda4.columns = ['Producto', 'Cantidad_Ventas']
producto_mas_vendido_tienda4 = ventas_por_producto_tienda4.iloc[0]
producto_menos_vendido_tienda4 = ventas_por_producto_tienda4.iloc[-1]

print(f"Producto más vendido en la tienda 1: {producto_mas_vendido_tienda1}")
print(f"Producto menos vendido en la tienda 1: {producto_menos_vendido_tienda1}")
print("##########")
print(f"Producto más vendido en la tienda 2: {producto_mas_vendido_tienda2}")
print(f"Producto menos vendido en la tienda 2: {producto_menos_vendido_tienda2}")
print("##########")
print(f"Producto más vendido en la tienda 3: {producto_mas_vendido_tienda3}")
print(f"Producto menos vendido en la tienda 3: {producto_menos_vendido_tienda3}")
print("##########")
print(f"Producto más vendido en la tienda 4: {producto_mas_vendido_tienda4}")
print(f"Producto menos vendido en la tienda 4: {producto_menos_vendido_tienda4}")
print("##########")
# Out:
# Producto más vendido en la tienda 1: Producto           TV LED UHD 4K
# Cantidad_Ventas               60
# Name: 0, dtype: object
# Producto menos vendido en la tienda 1: Producto           Celular ABXY
# Cantidad_Ventas              33
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 2: Producto           Iniciando en programación
# Cantidad_Ventas                           65
# Name: 0, dtype: object
# Producto menos vendido en la tienda 2: Producto           Juego de mesa
# Cantidad_Ventas               32
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 3: Producto           Kit de bancas
# Cantidad_Ventas               57
# Name: 0, dtype: object
# Producto menos vendido en la tienda 3: Producto           Bloques de construcción
# Cantidad_Ventas                         35
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 4: Producto           Cama box
# Cantidad_Ventas          62
# ...

# %%
# Out:
# Producto más vendido en la tienda 1: Producto           TV LED UHD 4K
# Cantidad_Ventas               60
# Name: 0, dtype: object
# Producto menos vendido en la tienda 1: Producto           Celular ABXY
# Cantidad_Ventas              33
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 2: Producto           Iniciando en programación
# Cantidad_Ventas                           65
# Name: 0, dtype: object
# Producto menos vendido en la tienda 2: Producto           Juego de mesa
# Cantidad_Ventas               32
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 3: Producto           Kit de bancas
# Cantidad_Ventas               57
# Name: 0, dtype: object
# Producto menos vendido en la tienda 3: Producto           Bloques de construcción
# Cantidad_Ventas                         35
# Name: 50, dtype: object
# ##########
# Producto más vendido en la tienda 4: Producto           Cama box
# Cantidad_Ventas          62
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
#calcular el costo de envío promedio para cada tienda
costo_envio_promedio_tienda1 = tienda['Costo de envío'].mean()
costo_envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
costo_envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
costo_envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

print(f"Costo envio promedio de la tienda 1: {costo_envio_promedio_tienda1}")
print('######')
print(f"Costo envio promedio de la tienda 2: {costo_envio_promedio_tienda2}")
print('######')
print(f"Costo envio promedio de la tienda 3: {costo_envio_promedio_tienda3}")
print('######')
print(f"Costo envio promedio de la tienda 4: {costo_envio_promedio_tienda4}")
# Out:
# Costo envio promedio de la tienda 1: 26018.60958033065
# ######
# Costo envio promedio de la tienda 2: 25216.235693090293
# ######
# Costo envio promedio de la tienda 3: 24805.680373039424
# ######
# Costo envio promedio de la tienda 4: 23459.457167090754

# %%
# Out:
# Costo envio promedio de la tienda 1: 26018.60958033065
# ######
# Costo envio promedio de la tienda 2: 25216.235693090293
# ######
# Costo envio promedio de la tienda 3: 24805.680373039424
# ######
# Costo envio promedio de la tienda 4: 23459.457167090754

# %% [markdown]
# # 🧾 Informe Final de Análisis de Tiendas
#
# ---
#
# ## **Introducción**
#
# El propósito de este análisis es determinar cuál de las cuatro tiendas representa la mejor oportunidad comercial para que el **Sr. Juan** venda sus productos.
# Para ello, se realizó un estudio comparativo considerando los siguientes factores clave:
# **ingresos totales**, **categorías de productos más y menos vendidas**, **calificación promedio de los clientes**, **productos con mayor y menor rotación**, y **costo de envío promedio**.
# Los resultados se presentan a continuación, acompañados de la justificación de la tienda recomendada.
#
# ---
#
# ## **Desarrollo del análisis**
#
# ### ** Ingresos totales**
#
# Los resultados financieros muestran que:
#
# La **Tienda 1** lidera con un ingreso total de **$1,150,880,400**
# La **Tienda 2** tiene un ingreso total de **$1,116,343,500**
# La **Tienda 3** tiene un ingreso total de **$1,098,019,600**
# La **Tienda 4** tiene un ingreso total de **$1,038,375,700**
#
# **Figura 1. Ingresos totales por tienda**
# *El gráfico de barras muestra que la Tienda 1 posee los mayores ingresos, mientras que la Tienda 4 tiene el menor desempeño. Las Tiendas 2 y 3 mantienen cifras competitivas.*
#
# ```python
# plt.bar(tiendas, ingresos_totales, color='skyblue', edgecolor='black')
# plt.title('Ingresos totales por tienda')
# plt.xlabel('Tienda')
# plt.ylabel('Ingresos ($)')
# plt.show()
# ```
#
# Aunque las diferencias no son extremas, la **Tienda 1** presenta el **mayor volumen de ingresos**, reflejando una posición fuerte en el mercado.
# ---
#
# ### ** Categorías de productos más y menos vendidas**
#
# El análisis de ventas por categoría evidencia que las categorías **“Muebles”** y **“Electrónicos”** concentran la mayor cantidad de ventas en todas las tiendas.
# En particular, *Muebles* alcanzó **465 ventas** en la Tienda 1, **499** en la Tienda 3 y **480** en la Tienda 4.
# Por otro lado, las categorías **“Artículos para el hogar”** y **“Libros”** se posicionan como las de menor rotación en los cuatro casos.
#
# **Figura 2. Ventas por categoría (Tienda 3)**
# *La Tienda 3 destaca por la amplia cantidad de ventas en la categoría Muebles, seguida de Electrónicos y Juguetes.*
#
# ```python
# plt.figure(figsize=(10,6))
# productos_vendidos_tienda3.sort_values(ascending=True).plot(kind='barh', color='lightgreen', edgecolor='black')
#
# plt.title('Cantidad de productos vendidos por categoría en la tienda 3')
# plt.xlabel('Cantidad de ventas')
# plt.ylabel('Categoría del Producto')
# plt.tight_layout()
# plt.show()
# ```
#
# Esto indica que las tiendas con un catálogo fuerte en productos de **alta demanda y mayor valor unitario** logran un desempeño más sólido, siendo la **Tienda 3** una de las que mejor equilibra volumen y diversidad de categorías.
#
# ---
#
# ### ** Calificación promedio**
#
# El nivel de satisfacción del cliente se midió con la calificación promedio obtenida por tienda:
#
# | Tienda | Calificación promedio |
# |:-------:|:--------------------:|
# | Tienda 1 | 3.98 |
# | Tienda 2 | 4.04 |
# | Tienda 3 | **4.05** |
# | Tienda 4 | 3.99 |
#
# **Figura 3. Calificación promedio por tienda**
# *El gráfico de puntos permite observar que la Tienda 3 tiene la mayor valoración general por parte de los clientes, seguida de la Tienda 2.*
#
# ```python
# plt.scatter(tiendas, promedios_totales, color='royalblue', s=100, edgecolor='black')
# plt.title('Calificación promedio por tienda')
# plt.xlabel('Tienda')
# plt.ylabel('Promedio de calificación')
# plt.ylim(0, 5)
# plt.grid(True, linestyle='--', alpha=0.6)
# plt.show()
# ```
#
# La **Tienda 3** presenta la **mejor valoración**, lo que indica **mayor satisfacción y fidelidad de los clientes** respecto a su experiencia de compra.
#
# ---
#
# ### ** Productos más y menos vendidos**
#
# | Tienda | Producto más vendido | Cantidad | Producto menos vendido | Cantidad |
# |:------:|:--------------------|:--------:|:----------------------|:--------:|
# | Tienda 1 | TV LED UHD 4K | 60 | Celular ABXY | 33 |
# | Tienda 2 | Iniciando en programación | 65 | Juego de mesa | 32 |
# | Tienda 3 | Kit de bancas | 57 | Bloques de construcción | 35 |
# | Tienda 4 | Cama box | 62 | Guitarra eléctrica | 33 |
#
# Los resultados reflejan que la **Tienda 3** posee una **mayor diversidad de productos vendidos**, lo que reduce la dependencia de un único tipo de artículo y amplía su alcance de mercado.
#
# ---
#
# ### ** Costo de envío promedio**
#
# | Tienda | Costo promedio de envío ($) |
# |:------:|:----------------------------:|
# | Tienda 1 | 26,018.61 |
# | Tienda 2 | 25,216.24 |
# | Tienda 3 | 24,805.68 |
# | Tienda 4 | **23,459.46** |
#
# Si bien la **Tienda 4** cuenta con el **menor costo de envío**, su nivel de ingresos y calificación promedio son inferiores.
# En cambio, la **Tienda 3** logra un equilibrio ideal entre **costos logísticos razonables** y **satisfacción del cliente alta**.
#
# ---
#
# ## **Conclusión y recomendación**
#
# Tras evaluar los distintos indicadores, se concluye que la **Tienda 3** es la **mejor opción para que el Sr. Juan venda sus productos**.
# Aunque no presenta el ingreso total más alto, combina:
#
# - ✅ **La calificación promedio más alta** (4.05)
# - ✅ **Amplia diversidad de productos vendidos**
# - ✅ **Categorías de alta rotación (Muebles y Electrónicos)**
# - ✅ **Costos de envío moderados**
# - ✅ **Ingresos totales competitivos**
#
# Estas fortalezas reflejan una tienda **rentable, bien valorada y con eficiencia logística**, lo que garantiza un entorno comercial estable y favorable para la venta de productos del Sr. Juan.
#
# **En conclusión**, la **Tienda 3** representa la alternativa más sólida, equilibrada y sostenible para la expansión del negocio del Sr. Juan.
#
# ---
